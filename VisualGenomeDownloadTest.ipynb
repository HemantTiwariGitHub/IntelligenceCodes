# %% [markdown]
# <a href="https://colab.research.google.com/github/HemantTiwariGitHub/IntelligenceCodes/blob/master/VisualGenomeDownloadTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install visual_genome
from visual_genome import api as vg
# Out:
# Collecting visual_genome
#   Downloading https://files.pythonhosted.org/packages/35/fb/a05a63edea9978a56fb25a07d7f0b91e2f3cd6e1ec890c2f9447c260f6a8/visual_genome-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: progressbar2 in /usr/local/lib/python2.7/dist-packages (from visual_genome) (3.38.0)
# Requirement already satisfied: requests in /usr/local/lib/python2.7/dist-packages (from visual_genome) (2.21.0)
# Requirement already satisfied: six in /usr/local/lib/python2.7/dist-packages (from progressbar2->visual_genome) (1.12.0)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python2.7/dist-packages (from progressbar2->visual_genome) (2.3.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests->visual_genome) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests->visual_genome) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests->visual_genome) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests->visual_genome) (2.8)
# Installing collected packages: visual-genome
# Successfully installed visual-genome-1.1.1

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from PIL import Image as PIL_Image
import requests
from io import StringIO

# %%
ids = vg.get_image_ids_in_range(2,100)
image_id = ids[0]
print "We got an image with id: %d" % image_id

# %matplotlib inline
# Out:
# We got an image with id: 3

# %%
image = vg.get_image_data(image_id)
print "The url of the image is: %s" % image.url
# Out:
# The url of the image is: https://cs.stanford.edu/people/rak248/VG_100K/3.jpg

# %%
print (image)
# Out:
# id: 3, coco_id: -1, flickr_id: -1, width: 640, url: https://cs.stanford.edu/people/rak248/VG_100K/3.jpg

# %%
regions = vg.get_region_descriptions_of_image(image_id)

# %%
print (regions)
# Out:
# [id: 1392, x: 455, y: 268, width: 96,height: 80, phrase: multi-line office phone system, image: 3, id: 1393, x: 40, y: 189, width: 87,height: 52, phrase: electrical and data line outlets, image: 3, id: 1394, x: 155, y: 125, width: 182,height: 352, phrase: desktop CPU, monitor and keyboard, image: 3, id: 1395, x: 1, y: 266, width: 133,height: 199, phrase: two-drawer filing cabinet, image: 3, id: 1396, x: 572, y: 272, width: 66,height: 134, phrase: black leather computer case, image: 3, id: 1442, x: 156, y: 269, width: 221,height: 60, phrase: A computer keyboard and mouse, image: 3, id: 1443, x: 440, y: 266, width: 129,height: 106, phrase: A wireless telephone on its base., image: 3, id: 1444, x: 212, y: 369, width: 88,height: 103, phrase: A computer tower under a desk, image: 3, id: 1445, x: 12, y: 319, width: 128,height: 149, phrase: A file cabinet next to the desk., image: 3, id: 1446, x: 38, y: 190, width: 97,height: 59, phrase: A multiple outlet with several plugs in it, image: 3, id: 1492, x: 452, y: 271, width: 103,height: 77, phrase: telephone on a desk, image: 3, id: 1493, x: 531, y: 94, width: 107,height: 143, phrase: girl sitting in front of a monitor, image: 3, id: 1494, x: 342, y: 297, width: 32,height: 29, phrase: mouse next to keyboard , image: 3, id: 1495, x: 40, y: 188, width: 86,height: 50, phrase: electrical outlets in the wall , image: 3, id: 1496, x: 125, y: 222, width: 512,height: 256, phrase: desk has a curved edge, image: 3, id: 1542, x: 568, y: 91, width: 66,height: 140, phrase: woman has long hair, image: 3, id: 1543, x: 590, y: 161, width: 36,height: 25, phrase: woman is wearing a chain , image: 3, id: 1544, x: 394, y: 323, width: 61,height: 23, phrase: a pen is on the desk, image: 3, id: 1545, x: 125, y: 352, width: 91,height: 124, phrase: cables are on the floor, image: 3, id: 1546, x: 179, y: 266, width: 170,height: 77, phrase: keyboard is white, image: 3, id: 1592, x: 339, y: 293, width: 39,height: 36, phrase: white computer mouse on desk, image: 3, id: 1593, x: 151, y: 121, width: 169,height: 151, phrase: computer monitor turned off, image: 3, id: 1594, x: 31, y: 177, width: 116,height: 74, phrase: four outlets on the wall, image: 3, id: 1595, x: 564, y: 260, width: 74,height: 152, phrase: black bag on the desk, image: 3, id: 1596, x: 421, y: 99, width: 98,height: 105, phrase: three-month calendar on wall, image: 3, id: 1642, x: 587, y: 101, width: 52,height: 105, phrase: woman has dark hair, image: 3, id: 1643, x: 404, y: 328, width: 48,height: 10, phrase: a blue pen on the desk, image: 3, id: 1644, x: 162, y: 129, width: 149,height: 127, phrase: monitor has been switched off, image: 3, id: 1645, x: 456, y: 280, width: 98,height: 60, phrase: black telephone is on the desk, image: 3, id: 1646, x: 545, y: 96, width: 93,height: 134, phrase: woman has white top, image: 3, id: 1692, x: 578, y: 92, width: 61,height: 115, phrase: A woman with dark hair in a ponytail, image: 3, id: 1693, x: 242, y: 48, width: 125,height: 51, phrase: Photos behind a partition, image: 3, id: 1694, x: 566, y: 272, width: 62,height: 179, phrase: A black case with a strap, image: 3, id: 1695, x: 540, y: 94, width: 92,height: 163, phrase: A woman with a white t-shirt, image: 3, id: 1696, x: 299, y: 89, width: 256,height: 190, phrase: A partition between cubicles, image: 3, id: 1742, x: 204, y: 1, width: 191,height: 37, phrase: picture are on the wall, image: 3, id: 1743, x: 448, y: 273, width: 98,height: 82, phrase: a black telephone on the desk, image: 3, id: 1744, x: 573, y: 103, width: 63,height: 113, phrase: a woman with black hair, image: 3, id: 1745, x: 565, y: 260, width: 72,height: 160, phrase: a black bag on the desk, image: 3, id: 1746, x: 334, y: 288, width: 48,height: 49, phrase: a white mouse on the desk, image: 3, id: 1792, x: 434, y: 104, width: 84,height: 85, phrase: calender has been hanged, image: 3, id: 1793, x: 334, y: 278, width: 40,height: 53, phrase: the mouse is white, image: 3, id: 1794, x: 403, y: 323 ...

# %%
 try:
    # %tensorflow_version 2.x
except:
    pass
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf
import tensorflow_hub as hub
print("\u2022 Using TensorFlow Version:", tf.__version__)
print("\u2022 Using TensorFlow Hub Version: ", hub.__version__)
print('\u2022 GPU Device Found.' if tf.test.is_gpu_available() else '\u2022 GPU Device Not Found. Running on CPU')
# Out:
# ('\\u2022 Using TensorFlow Version:', '2.1.0-rc1')
# ('\\u2022 Using TensorFlow Hub Version: ', '0.5.0')
# WARNING:tensorflow:From <ipython-input-15-8bb5014d1289>:5: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# \u2022 GPU Device Not Found. Running on CPU

# %%
MOBILENET_V2_FEATURE_EXTRACTOR_URI = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
PIXEL =224
INPUT_IMAGE_SIZE = (PIXEL, PIXEL)
OUTPUT_FEATURE_VECTOR_SIZE = 1280

# %%
feature_extractor = hub.KerasLayer(MOBILENET_V2_FEATURE_EXTRACTOR_URI,
                                   input_shape=INPUT_IMAGE_SIZE + (3,), 
                                   output_shape=[OUTPUT_FEATURE_VECTOR_SIZE],
                                   trainable=False)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-17-6091b9c67bdd> in <module>()
#       2                                    input_shape=INPUT_IMAGE_SIZE + (3,),
#       3                                    output_shape=[OUTPUT_FEATURE_VECTOR_SIZE],
# ----> 4                                    trainable=False)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow_hub/keras_layer.pyc in __init__(self, handle, trainable, arguments, **kwargs)
#     102       self._func = handle
#     103     else:
# --> 104       self._func = module_v2.load(handle)
#     105       if not callable(self._func):
#     106         raise ValueError("Non-callable result from hub.load('%s')" %
#
# /usr/local/lib/python2.7/dist-packages/tensorflow_hub/module_v2.pyc in load(handle, tags)
#      75   if hasattr(tf_v1.saved_model, "load_v2"):
#      76     module_handle = resolve(handle)
# ---> 77     return tf_v1.saved_model.load_v2(module_handle, tags=tags)
#      78   else:
#      79     raise NotImplementedError("hub.load() is not implemented for TF < 1.14.x, "
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/saved_model/load.pyc in load(export_dir, tags)
#     526     ValueError: If `tags` don't match a MetaGraph in the SavedModel.
#     527   """
# --> 528   return load_internal(export_dir, tags)
#     529
#     530
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/saved_model/load.pyc in load_internal(export_dir, tags, loader_cls)
#     550       loader = loader_cls(object_graph_proto,
#     551                           saved_model_proto,
# --> 552                           export_dir)
#     553       root = loader.get(0)
#     554     root.tensorflow_version = meta_graph_def.meta_info_def.tensorflow_version
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/saved_model/load.pyc in __init__(self, object_graph_proto, saved_model_proto, export_dir)
#     119       self._concrete_functions[name] = _WrapperFunction(concrete_function)
#     120
# --> 121     self._load_all()
#     122     # TODO(b/124045874): There are limitations with functions whose captures
#     123     # trigger other functions to be executed. For now it is only guaranteed to
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/saved_model/load.pyc in _load_all(self)
#     237         # interface.
#     238         continue
# --> 239       node, setter = self._recreate(proto)
#     240       nodes[node_id] = node
#     241       node_setters[node_id] = setter
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/saved_model/load.pyc in _recreate(self, proto)
#     320     if kind not in factory:
#     321       raise ValueError("Unknown SavedObject type: %r" % kind)
# --> 322     return factory[kind]()
#     323
#     324   def _recreate_user_object(self, proto):
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/saved_model/load.pyc in <lambda>()
#     313             self._recreate_bare_concrete_function,
#     314             proto.bare_concrete_function),
# --> 315         "variable": lambda: self._recreate_variable(proto.variable),
#     316         "constant": lambda: self._recreate_constant(proto.constant),
#     317         "resource": lambda: self._recreate_resource(proto.resource),
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/saved_model/load.pyc in _recreate_variable(self, proto)
#     382           trainable=trainable,
#     383           synchronization=synchronization,
# --> 384           aggregation=aggregation), setattr
#     385
#     386   def _recreate_constant(self, proto):
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/ops/variables.pyc in __call__(cls, *args, **kwargs)
#     258       return cls._variable_v1_call(*args, **kwargs)
#     259     elif cls is Variable:
# --> 260       return cls._variable_v2_call(*args, **kwargs)
#     261     else:
#     262       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/ops/variables.pyc in _variable_v2_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape)
#     252         synchronization=synchronization,
#     253         aggregation=aggregation,
# --> 254         shape=shape)
#     255
#     256   def __call__(cls, *args, **kwargs):
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/ops/variables.pyc in getter(**kwargs)
#      63
#      64   def getter(**kwargs):
# ---> 65     return captured_getter(captured_previous, **kwargs)
#      66
#      67   return getter
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/saved_model/load.pyc in uninitialized_variable_creator(***failed resolving arguments***)
#     368       """A variable creator that creates uninitialized variables."""
#     369       del next_creator
# --> 370       return resource_variable_ops.UninitializedVariable(**kwargs)
#     371
#     372     # Create a variable_creator_scope that creates uninitialized variables with
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/ops/variables.pyc in __call__(cls, *args, **kwargs)
#     260       return cls._variable_v2_call(*args, **kwargs)
#     261     else:
# --> 262       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     263
#     264
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/ops/resource_variable_ops.pyc in __init__(self, trainable, caching_device, name, shape, dtype, constraint, synchronization, aggregation, extra_handle_data, distribute_strategy, **unused_kwargs)
#    1765             shape=shape, dtype=dtype, shared_name=shared_name,
#    1766             name=name, graph_mode=self._in_graph_mode,
# -> 1767             initial_value=extra_handle_data)
#    1768         if not context.executing_eagerly():
#    1769           with ops.name_scope("Read"):
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/ops/resource_variable_ops.pyc in _variable_handle_from_shape_and_dtype(shape, dtype, shared_name, name, graph_mode, initial_value)
#     166     handle_data = cpp_shape_inference_pb2.CppShapeInferenceResult.HandleData()
#     167     handle_data.is_set = True
# --> 168     handle_data.shape_and_type.append(
#     169         cpp_shape_inference_pb2.CppShapeInferenceResult.HandleShapeAndType(
#     170             shape=shape.as_proto(), dtype=dtype.as_datatype_enum))
#
# AttributeError: 'google.protobuf.pyext._message.RepeatedCompositeCo' object has no attribute 'append'

# %%
import numpy as np
import PIL.Image as Image

# %%
image1 = tf.keras.utils.get_file("ds.jpg",image.url)
# Out:
# Downloading data from https://cs.stanford.edu/people/rak248/VG_100K/3.jpg
# 90112/85740 [===============================] - 0s 0us/step
# 98304/85740 [==================================] - 0s 0us/step

# %%
image1.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-24-8ec366e76e8c> in <module>()
# ----> 1 image1.show()
#
# AttributeError: 'str' object has no attribute 'show'

# %%
  resized_img = Image.open(image1).resize(INPUT_IMAGE_SIZE)

# %%
resized_img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FE9C3153B90>
