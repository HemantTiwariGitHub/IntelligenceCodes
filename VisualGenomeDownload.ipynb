# %% [markdown]
# <a href="https://colab.research.google.com/github/HemantTiwariGitHub/IntelligenceCodes/blob/master/VisualGenomeDownload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install visual_genome
from visual_genome import api as vg

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from PIL import Image as PIL_Image
import requests
from io import StringIO

# %%
ids = vg.get_image_ids_in_range(2,100)
image_id = ids[0]
print "We got an image with id: %d" % image_id

# %matplotlib inline

# %%
image = vg.get_image_data(image_id)
print "The url of the image is: %s" % image.url

# %%
print (image)

# %%
regions = vg.get_region_descriptions_of_image(image_id)

# %%
print (regions)

# %%
 try:
    # %tensorflow_version 2.x
except:
    pass

# %%
import tensorflow as tf
import tensorflow_hub as hub
print("\u2022 Using TensorFlow Version:", tf.__version__)
print("\u2022 Using TensorFlow Hub Version: ", hub.__version__)
print('\u2022 GPU Device Found.' if tf.test.is_gpu_available() else '\u2022 GPU Device Not Found. Running on CPU')

# %%
MOBILENET_V2_FEATURE_EXTRACTOR_URI = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
PIXEL =224
INPUT_IMAGE_SIZE = (PIXEL, PIXEL)
OUTPUT_FEATURE_VECTOR_SIZE = 1280

# %%
feature_extractor = hub.KerasLayer(MOBILENET_V2_FEATURE_EXTRACTOR_URI,
                                   input_shape=INPUT_IMAGE_SIZE + (3,), 
                                   output_shape=[OUTPUT_FEATURE_VECTOR_SIZE],
                                   trainable=False)

# %%
import numpy as np
import PIL.Image as Image

# %%
image1 = tf.keras.utils.get_file("ds.jpg",image.url)

# %%
image1.show()

# %%
  resized_img = Image.open(image1).resize(INPUT_IMAGE_SIZE)

# %%
resized_img

# %%
region_graph = vg.get_region_desc_of_image(image_id)
print(region_graph)

# %%
sg = vg.get_scene_graph_of_image(image_id)
print(sg)

# %%
# study  https://cs.stanford.edu/people/ranjaykrishna/sgrl/index.html

# %%
regions = vg.get_region_descriptions_of_image(image_id)

# %%
print (regions[3])
# Out:
# id: 1395, x: 1, y: 266, width: 133,height: 199, phrase: two-drawer filing cabinet, image: 3

# %%
resized_img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F55D3B84F90>

# %%
image2 = tf.keras.utils.get_file("ds.jpg",image.url)

# %%
oI2 = Image.open(image1)

# %%
oI2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F55D3C04850>

# %%
print (regions[3])
# Out:
# id: 1395, x: 1, y: 266, width: 133,height: 199, phrase: two-drawer filing cabinet, image: 3

# %%
# Out:
# 40

# %%
index =6
newImg =oI2.crop((regions[index].x, regions[index].y, regions[index].x + regions[index].width, regions[index].y + regions[index].height))
print(regions[index].phrase)
print(regions[index].image)
newImg
# Out:
# A wireless telephone on its base.
# id: 3, coco_id: -1, flickr_id: -1, width: 640, url: https://cs.stanford.edu/people/rak248/VG_100K/3.jpg
# <PIL.Image.Image image mode=RGB size=129x106 at 0x7F55D5F08B90>

# %%
# video bert https://arxiv.org/pdf/1904.01766.pdf

# %%
# Now Linguistic Embedding https://www.tensorflow.org/lite/models/bert_qa/overview

# %%
# https://tfhub.dev/google/elmo/3

# %%
elmo1 = hub.Module("https://tfhub.dev/google/elmo/3", trainable=False)
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-62-f76bb8ff077b> in <module>()
# ----> 1 elmo1 = hub.Module("https://tfhub.dev/google/elmo/3", trainable=False)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow_hub/module.pyc in __init__(self, spec, trainable, name, tags)
#     154       raise ValueError("No such graph variant: tags=%r" % tags)
#     155
# --> 156     abs_state_scope = _try_get_state_scope(name, mark_name_scope_used=False)
#     157     self._name = abs_state_scope.split("/")[-2]
#     158
#
# /usr/local/lib/python2.7/dist-packages/tensorflow_hub/module.pyc in _try_get_state_scope(name, mark_name_scope_used)
#     387       raise RuntimeError(
#     388           "variable_scope %s was unused but the corresponding "
# --> 389           "name_scope was already taken." % abs_state_scope)
#     390   return abs_state_scope
#     391
#
# RuntimeError: variable_scope module_2/ was unused but the corresponding name_scope was already taken.

# %%
# https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/1
